# %%
import pandas as pd
import seaborn as sns
#sns.set_theme(style="ticks", palette="pastel")

# %%
#d = {'col1': [1, 2], 'col2': [3, 4]}
columns = ["Ref","Dataset","Acc","Sens","Spec","Prec","F1"]
d = [["Sannino2018","MITDB",99.68,float("nan"),float("nan"),float("nan"),float("nan")],
    #["Li2018","cinc2000",100,100,100,float("nan"),float("nan")],
    ["Ghiasi2017","CinC'17",71,float("nan"),float("nan"),float("nan"),float("nan")],
    ["Chamatidis2017a","PTB",86.97,float("nan"),float("nan"),float("nan"),float("nan")],
    ["Chamatidis2017b","PTB",85.75,float("nan"),float("nan"),float("nan"),float("nan")],
    ["Chamatidis2017c","PTB",85.87,float("nan"),float("nan"),float("nan"),float("nan")],
    ["Chamatidis2017d","PTB",88.45,float("nan"),float("nan"),float("nan"),float("nan")],
    ["Chamatidis2017e","PTB",80,float("nan"),float("nan"),float("nan"),float("nan")],
    ["Majumdar2017","MITDB",97,float("nan"),float("nan"),float("nan"),float("nan")],
    ["Luo2017a","MITDB",99.1,93.3,99.5,93.3,float("nan")],
    ["Luo2017b","MITDB",98.8,71.4,99.8,94.4,float("nan")],
    ["Sadrawi2017a","MITDB",float("nan"),93.1,float("nan"),67.14,float("nan")],
    ["Sadrawi2017b","MITDB",float("nan"),79.87,float("nan"),67.14,float("nan")],
    ["Liu2018a","PTB",99.95,float("nan"),float("nan"),float("nan"),float("nan")],
    ["Liu2018b","PTB",98.79,float("nan"),float("nan"),float("nan"),float("nan")],
    ["Labati2018","PTB",100,float("nan"),float("nan"),float("nan"),float("nan")],
    ["TakaloMattila2018a","MITDB",float("nan"),92,float("nan"),97,float("nan")],
    ["TakaloMattila2018b","MITDB",float("nan"),62,float("nan"),56,float("nan")],
    ["TakaloMattila2018c","MITDB",float("nan"),89,float("nan"),51,float("nan")],
    ["Plesinger2017","CinC'17",float("nan"),float("nan"),float("nan"),float("nan"),81],
    ["Rubin2018","CinC'17",float("nan"),float("nan"),float("nan"),float("nan"),82],
    ["Xia2017a","MIT-BIH AF",98.29,98.34,98.24,float("nan"),float("nan")],
    ["Xia2017b","MIT-BIH AF",98.63,98.79,97.87,float("nan"),float("nan")],
    ["Kamaleswaran2018a","CinC'17",76.79,float("nan"),float("nan"),float("nan"),84],
    ["Kamaleswaran2018b","CinC'17",74.84,float("nan"),float("nan"),float("nan"),84],
    ["Zhai2018a","MITDB",98.6,93.8,99.2,float("nan"),float("nan")],
    ["Zhai2018b","MITDB",97.6,76.8,98.7,float("nan"),float("nan")],
    ["Jun2018","MITDB",99.05,97.85,float("nan"),float("nan"),float("nan")],
    ["Andreotti2017a","CinC'17",float("nan"),float("nan"),float("nan"),float("nan"),79],
    ["Andreotti2017b","CinC'17",float("nan"),float("nan"),float("nan"),float("nan"),83],
    ["Acharya2017a","MIT-BIH AF",92.5,98.09,93.13,float("nan"),float("nan")],
    ["Acharya2017b","MIT-BIH AF",94.9,99.13,81.44,float("nan"),float("nan")],
    ["Yildirim2018a","MITDB",91.33,float("nan"),float("nan"),float("nan"),float("nan")],
    ["Fan2018a","CinC'17",96.99,float("nan"),float("nan"),float("nan"),float("nan")],
    ["Fan2018b","CinC'17",98.13,float("nan"),float("nan"),float("nan"),float("nan")],
    ["Zhong2018","CinC'17",float("nan"),float("nan"),float("nan"),float("nan"),float("nan")],
    ["Li2018a","MITDB",98.6,77.2,99.8,96.6,float("nan")],
    ["Li2018b","MITDB",98.3,68.7,99.8,94.7,float("nan")],
    ["Li2017","MITDB",97.5,float("nan"),float("nan"),float("nan"),float("nan")],
    ["Acharya2017c","MITDB",94.03,96.71,91.54,float("nan"),float("nan")],
    ["Liu2017","PTB",96,95.4,97.37,float("nan"),float("nan")],
    ["Xia2017c","MITDB",98.63,98.79,97.87,float("nan"),float("nan")],
    ["Xiong2017a","CinC'17",90,float("nan"),float("nan"),float("nan"),float("nan")],
    ["Xiong2017b","CinC'17",82,float("nan"),float("nan"),float("nan"),float("nan")],
    ["Xiong2017c","CinC'17",75,float("nan"),float("nan"),float("nan"),float("nan")],
    ["Isin2017a","MITDB",92.4,float("nan"),float("nan"),float("nan"),float("nan")],
    ["Isin2017b","MITDB",91.2,float("nan"),float("nan"),float("nan"),float("nan")],
    ["Isin2017c","MITDB",85,float("nan"),float("nan"),float("nan"),float("nan")],
    ["Xu2018","MITDB",81.07,74.96,float("nan"),float("nan"),float("nan")],
    ["Xiang2018","MITDB",99.68,99.77,float("nan"),99.91,float("nan")],
    ["Sodmann2018","CinC'17",float("nan"),float("nan"),float("nan"),float("nan"),82],
    ["Taji2018","MIT-BIH AF",81,68.1,85,65,float("nan")],
    ["Maknickas2017","CinC'17",float("nan"),float("nan"),float("nan"),float("nan"),78],
    ["Singh2018a","MITDB",85.4,80.6,85.7,float("nan"),float("nan")],
    ["Singh2018b","MITDB",82.5,78.9,81.5,float("nan"),float("nan")],
    ["Singh2018c","MITDB",85.4,80.6,85.7,float("nan"),float("nan")],
    ["Singh2018d","MITDB",82.5,78.9,81.5,float("nan"),float("nan")],
    ["Singh2018e","MITDB",88.1,92.4,83.4,float("nan"),float("nan")],
    ["Zhang2017a","MITDB",99.7,97.1,99.9,98.1,float("nan")],
    ["Zhang2017b","MITDB",99.3,85.9,99.7,88.7,float("nan")],
    ["Sujadevi2017","MITDB",95,88.9,float("nan"),100,94.1],
    ["Yildirim2018ab","MITDB",99.39,float("nan"),float("nan"),float("nan"),float("nan")],
    ["Faust2018","MITDB",98.51,98.32,98.67,98.39,float("nan")],
    ["Schwab2017","CinC'17",float("nan"),float("nan"),float("nan"),float("nan"),79],
    ["Sujadevi2017","MITDB",100,100,float("nan"),100,100],
    ]

df = pd.DataFrame(data=d,columns=columns)

df
# Out:
#                 Ref  Dataset     Acc    Sens   Spec    Prec     F1
# 0       Sannino2018    MITDB   99.68     NaN    NaN     NaN    NaN
# 1        Ghiasi2017  CinC'17   71.00     NaN    NaN     NaN    NaN
# 2   Chamatidis2017a      PTB   86.97     NaN    NaN     NaN    NaN
# 3   Chamatidis2017b      PTB   85.75     NaN    NaN     NaN    NaN
# 4   Chamatidis2017c      PTB   85.87     NaN    NaN     NaN    NaN
# ..              ...      ...     ...     ...    ...     ...    ...
# 59     Sujadevi2017    MITDB   95.00   88.90    NaN  100.00   94.1
# 60   Yildirim2018ab    MITDB   99.39     NaN    NaN     NaN    NaN
# 61        Faust2018    MITDB   98.51   98.32  98.67   98.39    NaN
# 62       Schwab2017  CinC'17     NaN     NaN    NaN     NaN   79.0
# 63     Sujadevi2017    MITDB  100.00  100.00    NaN  100.00  100.0
#
# [64 rows x 7 columns]

# %%
df1= df[["Ref","Dataset","Acc"]].copy().rename(columns={"Acc":"Metric value"})
df1['Metric type'] = "Acc"
df2= df[["Ref","Dataset","Sens"]].copy().rename(columns={"Sens":"Metric value"})
df2['Metric type'] = "Sens"
df3= df[["Ref","Dataset","Spec"]].copy().rename(columns={"Spec":"Metric value"})
df3['Metric type'] = "Spec"
df4= df[["Ref","Dataset","Prec"]].copy().rename(columns={"Prec":"Metric value"})
df4['Metric type'] = "Prec"
df5= df[["Ref","Dataset","F1"]].copy().rename(columns={"F1":"Metric value"})
df5['Metric type'] = "F1"

df_new = pd.concat([df1,df2,df3,df4,df5])
df_new = df_new.reset_index(drop=True)

# %%
# Draw a nested boxplot to show bills by day and time
ax = sns.boxplot(x="Dataset", y="Metric value",hue="Metric type",palette=["r","g","b","c","m"],data=df_new)
ax.grid()
fig = ax.get_figure()
fig.savefig("2_ecg_sota_metric.png", dpi=600)
#sns.despine(offset=10, trim=True)
